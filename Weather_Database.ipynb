# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key

# Import the requests library.
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Perform API call URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c766dae17b661fbc746c1d6e947ca4ac

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
     
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | athabasca
# Processing Record 3 of Set 1 | bonfim
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | rathdrum
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | half moon bay
# Processing Record 11 of Set 1 | walvis bay
# Processing Record 12 of Set 1 | jieshou
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | karratha
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | souillac
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | iida
# Processing Record 22 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | rocha
# Processing Record 30 of Set 1 | savinka
# Processing Record 31 of Set 1 | phonhong
# Processing Record 32 of Set 1 | charters towers
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | arraial do cabo
# Processing Record 35 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | east london
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | caconda
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | mackay
# Processing Record 42 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | balaipungut
# Processing Record 44 of Set 1 | okahandja
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | nur
# Processing Record 49 of Set 1 | klaksvik
# Processing Record 50 of Set 1 | hirara
# Processing Record 1 of Set 2 | vardo
# Processing Record 2 of Set 2 | vila velha
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | hokitika
# Processing Record 5 of Set 2 | gurlan
# Processing Record 6 of Set 2 | tikrit
# Processing Record 7 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 2 | itaituba
# Processing Record 9 of Set 2 | nenjiang
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | victoria
# Processing Record 13 of Set 2 | jining
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | spartanburg
# Processing Record 16 of Set 2 | edendale
# Processing Record 17 of Set 2 | cherskiy
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | kaitangata
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | panguipulli
# Processing Record 23 of Set 2 | sarangani
# Processing Record 24 of Set 2 | mercedes
# Processing Record 25 of Set 2 | snina
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | mokhotlong
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | key largo
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | brandon
# Processing Record 32 of Set 2 | ashland
# Processing Record 33 of Set 2 | krasnoselkup
# Processing Record 34 of Set 2 | the pas
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | gamba
# Processing Record 37 of Set 2 | saint-georges
# Processing Record 38 of Set 2 | caravelas
# Processing Record 39 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 2 | shubarshi
# Processing Record 41 of Set 2 | saint-pierre
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | amapa
# Processing Record 44 of Set 2 | havre-saint-pierre
# Processing Record 45 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 2 | esperance
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | beringovskiy
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | gafanha da encarnacao
# Processing Record 2 of Set 3 | bardiyah
# Processing Record 3 of Set 3 | jutai
# Processing Record 4 of Set 3 | avarua
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | hualmay
# Processing Record 7 of Set 3 | muisne
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | plainview
# Processing Record 10 of Set 3 | mocuba
# Processing Record 11 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 12 of Set 3 | chara
# Processing Record 13 of Set 3 | dyurtyuli
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | clyde river
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | alice town
# Processing Record 20 of Set 3 | lima
# Processing Record 21 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 3 | evinayong
# Processing Record 23 of Set 3 | knysna
# Processing Record 24 of Set 3 | bluff
# Processing Record 25 of Set 3 | garcia hernandez
# Processing Record 26 of Set 3 | pevek
# Processing Record 27 of Set 3 | vila franca do campo
# Processing Record 28 of Set 3 | kahului
# Processing Record 29 of Set 3 | tasiilaq
# Processing Record 30 of Set 3 | bethel
# Processing Record 31 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 3 | inverness
# Processing Record 33 of Set 3 | secunda
# Processing Record 34 of Set 3 | chengde
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 3 | ancud
# Processing Record 38 of Set 3 | nalut
# Processing Record 39 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 3 | margate
# Processing Record 41 of Set 3 | george
# Processing Record 42 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 3 | elat
# Processing Record 44 of Set 3 | lufilufi
# Processing Record 45 of Set 3 | kodinsk
# Processing Record 46 of Set 3 | lorengau
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | calama
# Processing Record 49 of Set 3 | tak bai
# Processing Record 50 of Set 3 | cansancao
# Processing Record 1 of Set 4 | aksaray
# Processing Record 2 of Set 4 | dryden
# Processing Record 3 of Set 4 | illela
# Processing Record 4 of Set 4 | sept-iles
# Processing Record 5 of Set 4 | batagay-alyta
# Processing Record 6 of Set 4 | lebu
# Processing Record 7 of Set 4 | quatre cocos
# Processing Record 8 of Set 4 | port lincoln
# Processing Record 9 of Set 4 | katsuura
# Processing Record 10 of Set 4 | ravenna
# Processing Record 11 of Set 4 | baykit
# Processing Record 12 of Set 4 | derazhnya
# Processing Record 13 of Set 4 | airai
# Processing Record 14 of Set 4 | srednekolymsk
# Processing Record 15 of Set 4 | lucapa
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | faanui
# Processing Record 19 of Set 4 | burley
# Processing Record 20 of Set 4 | nantucket
# Processing Record 21 of Set 4 | zabol
# Processing Record 22 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | velingara
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | kitami
# Processing Record 27 of Set 4 | chapais
# Processing Record 28 of Set 4 | gongzhuling
# Processing Record 29 of Set 4 | mar del plata
# Processing Record 30 of Set 4 | lagoa
# Processing Record 31 of Set 4 | bandarbeyla
# Processing Record 32 of Set 4 | hofn
# Processing Record 33 of Set 4 | payyannur
# Processing Record 34 of Set 4 | lerwick
# Processing Record 35 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 4 | ishigaki
# Processing Record 37 of Set 4 | nichinan
# Processing Record 38 of Set 4 | tiksi
# Processing Record 39 of Set 4 | vieste
# Processing Record 40 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 41 of Set 4 | khandyga
# Processing Record 42 of Set 4 | meadow lake
# Processing Record 43 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 4 | yaan
# Processing Record 45 of Set 4 | torbay
# Processing Record 46 of Set 4 | ransang
# Processing Record 47 of Set 4 | saint-augustin
# Processing Record 48 of Set 4 | nelson bay
# Processing Record 49 of Set 4 | thunder bay
# Processing Record 50 of Set 4 | guarapari
# Processing Record 1 of Set 5 | namibe
# Processing Record 2 of Set 5 | pushkino
# Processing Record 3 of Set 5 | ust-kut
# Processing Record 4 of Set 5 | port blair
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | matay
# Processing Record 7 of Set 5 | brookhaven
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | mount darwin
# Processing Record 10 of Set 5 | merauke
# Processing Record 11 of Set 5 | trincomalee
# Processing Record 12 of Set 5 | wichita falls
# Processing Record 13 of Set 5 | les cayes
# Processing Record 14 of Set 5 | college
# Processing Record 15 of Set 5 | zambezi
# Processing Record 16 of Set 5 | issia
# Processing Record 17 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 18 of Set 5 | mahebourg
# Processing Record 19 of Set 5 | gorontalo
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | obsharovka
# Processing Record 22 of Set 5 | kathmandu
# Processing Record 23 of Set 5 | douentza
# Processing Record 24 of Set 5 | puerto escondido
# Processing Record 25 of Set 5 | geraldton
# Processing Record 26 of Set 5 | gasa
# Processing Record 27 of Set 5 | asau
# Processing Record 28 of Set 5 | wamba
# Processing Record 29 of Set 5 | tecoanapa
# Processing Record 30 of Set 5 | orlik
# Processing Record 31 of Set 5 | harlingen
# Processing Record 32 of Set 5 | vzmorye
# Processing Record 33 of Set 5 | sorland
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | wladyslawowo
# Processing Record 37 of Set 5 | komsomolskiy
# Processing Record 38 of Set 5 | moose factory
# Processing Record 39 of Set 5 | alice springs
# Processing Record 40 of Set 5 | vila
# Processing Record 41 of Set 5 | saint-joseph
# Processing Record 42 of Set 5 | varia
# Processing Record 43 of Set 5 | kununurra
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | makakilo city
# Processing Record 46 of Set 5 | gubkinskiy
# Processing Record 47 of Set 5 | wanning
# Processing Record 48 of Set 5 | voznesenskoye
# Processing Record 49 of Set 5 | gunjur
# Processing Record 50 of Set 5 | folldal
# Processing Record 1 of Set 6 | alexandria
# Processing Record 2 of Set 6 | dutlwe
# Processing Record 3 of Set 6 | grindavik
# Processing Record 4 of Set 6 | severo-kurilsk
# Processing Record 5 of Set 6 | krasnoarmeysk
# Processing Record 6 of Set 6 | ambulu
# Processing Record 7 of Set 6 | ostrovnoy
# Processing Record 8 of Set 6 | san cristobal
# Processing Record 9 of Set 6 | takoradi
# Processing Record 10 of Set 6 | dingle
# Processing Record 11 of Set 6 | olovyannaya
# Processing Record 12 of Set 6 | reefton
# City not found. Skipping...
# Processing Record 13 of Set 6 | ilulissat
# Processing Record 14 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 6 | arlit
# Processing Record 16 of Set 6 | hambantota
# Processing Record 17 of Set 6 | villacarrillo
# Processing Record 18 of Set 6 | tocopilla
# Processing Record 19 of Set 6 | kijang
# Processing Record 20 of Set 6 | broken hill
# Processing Record 21 of Set 6 | launceston
# Processing Record 22 of Set 6 | takaka
# Processing Record 23 of Set 6 | ingham
# Processing Record 24 of Set 6 | calategas
# City not found. Skipping...
# Processing Record 25 of Set 6 | rawson
# Processing Record 26 of Set 6 | quelimane
# Processing Record 27 of Set 6 | sampit
# Processing Record 28 of Set 6 | north bend
# Processing Record 29 of Set 6 | gitega
# Processing Record 30 of Set 6 | curuguaty
# Processing Record 31 of Set 6 | haines junction
# Processing Record 32 of Set 6 | hazebrouck
# Processing Record 33 of Set 6 | la rioja
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | hay river
# Processing Record 36 of Set 6 | aguimes
# Processing Record 37 of Set 6 | rudnogorsk
# Processing Record 38 of Set 6 | terra rica
# Processing Record 39 of Set 6 | monrovia
# Processing Record 40 of Set 6 | bannu
# Processing Record 41 of Set 6 | montrose
# Processing Record 42 of Set 6 | bahia honda
# Processing Record 43 of Set 6 | tapiramuta
# Processing Record 44 of Set 6 | udachnyy
# Processing Record 45 of Set 6 | saiki
# Processing Record 46 of Set 6 | maceio
# Processing Record 47 of Set 6 | buala
# Processing Record 48 of Set 6 | djang
# City not found. Skipping...
# Processing Record 49 of Set 6 | nizwa
# Processing Record 50 of Set 6 | osypenko
# Processing Record 1 of Set 7 | oyama
# Processing Record 2 of Set 7 | semnan
# Processing Record 3 of Set 7 | huarmey
# Processing Record 4 of Set 7 | hasaki
# Processing Record 5 of Set 7 | codrington
# Processing Record 6 of Set 7 | lasa
# Processing Record 7 of Set 7 | zelenoborskiy
# Processing Record 8 of Set 7 | dharchula
# Processing Record 9 of Set 7 | naryan-mar
# Processing Record 10 of Set 7 | dhidhdhoo
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | plouzane
# Processing Record 13 of Set 7 | talas
# Processing Record 14 of Set 7 | guerrero negro
# Processing Record 15 of Set 7 | oda
# Processing Record 16 of Set 7 | rehoboth
# Processing Record 17 of Set 7 | pangnirtung
# Processing Record 18 of Set 7 | constitucion
# Processing Record 19 of Set 7 | altagracia de orituco
# Processing Record 20 of Set 7 | christchurch
# Processing Record 21 of Set 7 | padang
# Processing Record 22 of Set 7 | erenhot
# Processing Record 23 of Set 7 | saskylakh
# Processing Record 24 of Set 7 | sitka
# Processing Record 25 of Set 7 | agutaya
# Processing Record 26 of Set 7 | faya
# Processing Record 27 of Set 7 | sao filipe
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | cayeli
# Processing Record 30 of Set 7 | bela
# Processing Record 31 of Set 7 | nanakuli
# Processing Record 32 of Set 7 | berlevag
# Processing Record 33 of Set 7 | aykhal
# Processing Record 34 of Set 7 | dongkan
# Processing Record 35 of Set 7 | mount gambier
# Processing Record 36 of Set 7 | yumen
# Processing Record 37 of Set 7 | verkhoyansk
# Processing Record 38 of Set 7 | katangli
# Processing Record 39 of Set 7 | kalmunai
# Processing Record 40 of Set 7 | bocas del toro
# Processing Record 41 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 42 of Set 7 | broadford
# Processing Record 43 of Set 7 | mecca
# Processing Record 44 of Set 7 | atlantic city
# Processing Record 45 of Set 7 | grand-santi
# Processing Record 46 of Set 7 | coahuayana
# Processing Record 47 of Set 7 | bogalusa
# Processing Record 48 of Set 7 | baiao
# Processing Record 49 of Set 7 | mikhaylovka
# Processing Record 50 of Set 7 | brae
# Processing Record 1 of Set 8 | lompoc
# Processing Record 2 of Set 8 | southbridge
# Processing Record 3 of Set 8 | broome
# Processing Record 4 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 5 of Set 8 | maxixe
# Processing Record 6 of Set 8 | bassano
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | nouadhibou
# Processing Record 9 of Set 8 | kavieng
# Processing Record 10 of Set 8 | aneho
# Processing Record 11 of Set 8 | sur
# Processing Record 12 of Set 8 | aloleng
# Processing Record 13 of Set 8 | la ronge
# Processing Record 14 of Set 8 | rio gallegos
# Processing Record 15 of Set 8 | freeport
# Processing Record 16 of Set 8 | aguilas
# Processing Record 17 of Set 8 | kolokani
# Processing Record 18 of Set 8 | waingapu
# Processing Record 19 of Set 8 | abu dhabi
# Processing Record 20 of Set 8 | voh
# Processing Record 21 of Set 8 | pathein
# Processing Record 22 of Set 8 | pao de acucar
# Processing Record 23 of Set 8 | miri
# Processing Record 24 of Set 8 | camacha
# Processing Record 25 of Set 8 | atar
# Processing Record 26 of Set 8 | kavaratti
# Processing Record 27 of Set 8 | sao joao da barra
# Processing Record 28 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 8 | kirkland lake
# Processing Record 30 of Set 8 | tevaitoa
# Processing Record 31 of Set 8 | aden
# Processing Record 32 of Set 8 | karasjok
# Processing Record 33 of Set 8 | grand-lahou
# Processing Record 34 of Set 8 | avera
# Processing Record 35 of Set 8 | kuytun
# Processing Record 36 of Set 8 | lavrentiya
# Processing Record 37 of Set 8 | saint george
# Processing Record 38 of Set 8 | eyl
# Processing Record 39 of Set 8 | klyuchi
# Processing Record 40 of Set 8 | lawton
# Processing Record 41 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 42 of Set 8 | sevlievo
# Processing Record 43 of Set 8 | sri aman
# Processing Record 44 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 45 of Set 8 | meulaboh
# Processing Record 46 of Set 8 | narsaq
# Processing Record 47 of Set 8 | leshukonskoye
# Processing Record 48 of Set 8 | wainwright
# Processing Record 49 of Set 8 | kjopsvik
# Processing Record 50 of Set 8 | lazaro cardenas
# Processing Record 1 of Set 9 | jalingo
# Processing Record 2 of Set 9 | el rodeo
# Processing Record 3 of Set 9 | maniitsoq
# Processing Record 4 of Set 9 | umm lajj
# Processing Record 5 of Set 9 | romodanovo
# Processing Record 6 of Set 9 | pemba
# Processing Record 7 of Set 9 | valparaiso
# Processing Record 8 of Set 9 | nouakchott
# Processing Record 9 of Set 9 | kropotkin
# Processing Record 10 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 9 | taoudenni
# Processing Record 12 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 9 | morehead
# Processing Record 14 of Set 9 | chuy
# Processing Record 15 of Set 9 | lincoln
# Processing Record 16 of Set 9 | saint-francois
# Processing Record 17 of Set 9 | dabat
# Processing Record 18 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 9 | izmaylovo
# Processing Record 21 of Set 9 | boo
# Processing Record 22 of Set 9 | hami
# Processing Record 23 of Set 9 | solnechnyy
# Processing Record 24 of Set 9 | vanimo
# Processing Record 25 of Set 9 | marawi
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | bathsheba
# Processing Record 28 of Set 9 | mannarakkat
# Processing Record 29 of Set 9 | ahuimanu
# Processing Record 30 of Set 9 | tazovskiy
# Processing Record 31 of Set 9 | ponta do sol
# Processing Record 32 of Set 9 | kingman
# Processing Record 33 of Set 9 | puerto del rosario
# Processing Record 34 of Set 9 | krasnorechenskiy
# Processing Record 35 of Set 9 | tugolesskiy bor
# Processing Record 36 of Set 9 | goundam
# Processing Record 37 of Set 9 | lamar
# Processing Record 38 of Set 9 | zapolyarnyy
# Processing Record 39 of Set 9 | port keats
# Processing Record 40 of Set 9 | aljezur
# Processing Record 41 of Set 9 | palmer
# Processing Record 42 of Set 9 | zharkent
# Processing Record 43 of Set 9 | roald
# Processing Record 44 of Set 9 | villarrica
# Processing Record 45 of Set 9 | divnoye
# Processing Record 46 of Set 9 | mandalgovi
# Processing Record 47 of Set 9 | mandal
# Processing Record 48 of Set 9 | osakarovka
# Processing Record 49 of Set 9 | diban
# Processing Record 50 of Set 9 | maarianhamina
# Processing Record 1 of Set 10 | oranjestad
# Processing Record 2 of Set 10 | vestmannaeyjar
# Processing Record 3 of Set 10 | antalaha
# Processing Record 4 of Set 10 | jiuquan
# Processing Record 5 of Set 10 | kidal
# Processing Record 6 of Set 10 | anadyr
# Processing Record 7 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 8 of Set 10 | garissa
# Processing Record 9 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 10 of Set 10 | port hardy
# Processing Record 11 of Set 10 | necochea
# Processing Record 12 of Set 10 | cap malheureux
# Processing Record 13 of Set 10 | sisimiut
# Processing Record 14 of Set 10 | agva
# City not found. Skipping...
# Processing Record 15 of Set 10 | ambilobe
# Processing Record 16 of Set 10 | leningradskiy
# Processing Record 17 of Set 10 | saratovskaya
# Processing Record 18 of Set 10 | isangel
# Processing Record 19 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 10 | jumla
# Processing Record 21 of Set 10 | tabou
# Processing Record 22 of Set 10 | plettenberg bay
# Processing Record 23 of Set 10 | nicoya
# Processing Record 24 of Set 10 | mayor pablo lagerenza
# Processing Record 25 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 10 | praia da vitoria
# Processing Record 27 of Set 10 | willowmore
# Processing Record 28 of Set 10 | vitim
# Processing Record 29 of Set 10 | mugur-aksy
# Processing Record 30 of Set 10 | zhigansk
# Processing Record 31 of Set 10 | dingolfing
# Processing Record 32 of Set 10 | galle
# Processing Record 33 of Set 10 | honiara
# Processing Record 34 of Set 10 | ha giang
# Processing Record 35 of Set 10 | koungou
# Processing Record 36 of Set 10 | maralal
# Processing Record 37 of Set 10 | okhotsk
# Processing Record 38 of Set 10 | zomin
# Processing Record 39 of Set 10 | flinders
# Processing Record 40 of Set 10 | del rio
# Processing Record 41 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 43 of Set 10 | jalu
# Processing Record 44 of Set 10 | tuatapere
# Processing Record 45 of Set 10 | san luis
# Processing Record 46 of Set 10 | mahibadhoo
# Processing Record 47 of Set 10 | dedza
# Processing Record 48 of Set 10 | hirado
# Processing Record 49 of Set 10 | governador valadares
# Processing Record 50 of Set 10 | ignacio zaragoza
# Processing Record 1 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 2 of Set 11 | clifton
# Processing Record 3 of Set 11 | codajas
# Processing Record 4 of Set 11 | kumbakonam
# Processing Record 5 of Set 11 | ugoofaaru
# Processing Record 6 of Set 11 | coihaique
# Processing Record 7 of Set 11 | itarema
# Processing Record 8 of Set 11 | beloha
# Processing Record 9 of Set 11 | lebyazhye
# Processing Record 10 of Set 11 | burica
# City not found. Skipping...
# Processing Record 11 of Set 11 | mujiayingzi
# Processing Record 12 of Set 11 | andros town
# Processing Record 13 of Set 11 | nuzvid
# Processing Record 14 of Set 11 | lethem
# Processing Record 15 of Set 11 | hastings
# Processing Record 16 of Set 11 | yingkou
# Processing Record 17 of Set 11 | kanigoro
# Processing Record 18 of Set 11 | cabedelo
# Processing Record 19 of Set 11 | kupang
# Processing Record 20 of Set 11 | langsa
# Processing Record 21 of Set 11 | ler
# Processing Record 22 of Set 11 | sal rei
# Processing Record 23 of Set 11 | kaberamaido
# Processing Record 24 of Set 11 | alofi
# Processing Record 25 of Set 11 | khandagayty
# Processing Record 26 of Set 11 | ponta pora
# Processing Record 27 of Set 11 | siderno
# Processing Record 28 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 11 | taua
# Processing Record 30 of Set 11 | barra
# Processing Record 31 of Set 11 | cockburn town
# Processing Record 32 of Set 11 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 11 | camocim
# Processing Record 34 of Set 11 | vilyuysk
# Processing Record 35 of Set 11 | shimoda
# Processing Record 36 of Set 11 | guilin
# Processing Record 37 of Set 11 | algeciras
# Processing Record 38 of Set 11 | beidao
# Processing Record 39 of Set 11 | fairfield
# Processing Record 40 of Set 11 | ambovombe
# Processing Record 41 of Set 11 | kuching
# Processing Record 42 of Set 11 | la peca
# Processing Record 43 of Set 11 | mosquera
# Processing Record 44 of Set 11 | tsogni
# Processing Record 45 of Set 11 | comodoro rivadavia
# Processing Record 46 of Set 11 | galveston
# Processing Record 47 of Set 11 | husavik
# Processing Record 48 of Set 11 | priladozhskiy
# Processing Record 49 of Set 11 | orange
# Processing Record 50 of Set 11 | poum
# Processing Record 1 of Set 12 | pimentel
# Processing Record 2 of Set 12 | gibara
# Processing Record 3 of Set 12 | mana
# Processing Record 4 of Set 12 | chilmari
# Processing Record 5 of Set 12 | taksimo
# Processing Record 6 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 7 of Set 12 | norman wells
# Processing Record 8 of Set 12 | burns lake
# Processing Record 9 of Set 12 | pacific grove
# Processing Record 10 of Set 12 | cifuentes
# Processing Record 11 of Set 12 | bodden town
# Processing Record 12 of Set 12 | amazar
# Processing Record 13 of Set 12 | palm coast
# Processing Record 14 of Set 12 | fairbanks
# Processing Record 15 of Set 12 | saint anthony
# Processing Record 16 of Set 12 | raudeberg
# Processing Record 17 of Set 12 | stykkisholmur
# Processing Record 18 of Set 12 | puerto maldonado
# Processing Record 19 of Set 12 | aksarka
# Processing Record 20 of Set 12 | stornoway
# Processing Record 21 of Set 12 | marrakesh
# Processing Record 22 of Set 12 | peterhead
# Processing Record 23 of Set 12 | mudyuga
# City not found. Skipping...
# Processing Record 24 of Set 12 | rubizhne
# Processing Record 25 of Set 12 | grand gaube
# Processing Record 26 of Set 12 | talcher
# Processing Record 27 of Set 12 | rio cuarto
# Processing Record 28 of Set 12 | kiruna
# Processing Record 29 of Set 12 | puerto colombia
# Processing Record 30 of Set 12 | opuwo
# Processing Record 31 of Set 12 | port-gentil
# Processing Record 32 of Set 12 | kemi
# Processing Record 33 of Set 12 | the valley
# Processing Record 34 of Set 12 | poso
# Processing Record 35 of Set 12 | ozernovskiy
# Processing Record 36 of Set 12 | mareeba
# Processing Record 37 of Set 12 | bensonville
# Processing Record 38 of Set 12 | anloga
# Processing Record 39 of Set 12 | nha trang
# Processing Record 40 of Set 12 | oranjemund
# Processing Record 41 of Set 12 | la libertad
# Processing Record 42 of Set 12 | yeppoon
# Processing Record 43 of Set 12 | moratuwa
# Processing Record 44 of Set 12 | fort frances
# Processing Record 45 of Set 12 | yulara
# Processing Record 46 of Set 12 | ulety
# Processing Record 47 of Set 12 | sanchez
# Processing Record 48 of Set 12 | usak
# Processing Record 49 of Set 12 | inhambane
# Processing Record 50 of Set 12 | san jose de guanipa
# Processing Record 1 of Set 13 | mehamn
# Processing Record 2 of Set 13 | garhshankar
# Processing Record 3 of Set 13 | villa carlos paz
# Processing Record 4 of Set 13 | harnosand
# Processing Record 5 of Set 13 | prainha
# Processing Record 6 of Set 13 | tezu
# Processing Record 7 of Set 13 | ngunguru
# Processing Record 8 of Set 13 | mount isa
# Processing Record 9 of Set 13 | laguna
# Processing Record 10 of Set 13 | odessa
# Processing Record 11 of Set 13 | ati
# Processing Record 12 of Set 13 | plonsk
# Processing Record 13 of Set 13 | lata
# Processing Record 14 of Set 13 | santa rosa
# Processing Record 15 of Set 13 | yurya
# City not found. Skipping...
# Processing Record 16 of Set 13 | rabaul
# Processing Record 17 of Set 13 | kashi
# Processing Record 18 of Set 13 | endicott
# Processing Record 19 of Set 13 | kattivakkam
# Processing Record 20 of Set 13 | san juan
# Processing Record 21 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 13 | linqu
# Processing Record 23 of Set 13 | black diamond
# Processing Record 24 of Set 13 | guaruja
# Processing Record 25 of Set 13 | marathon
# Processing Record 26 of Set 13 | terrace
# Processing Record 27 of Set 13 | alibag
# Processing Record 28 of Set 13 | paldiski
# Processing Record 29 of Set 13 | jiwani
# Processing Record 30 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 13 | atka
# City not found. Skipping...
# Processing Record 32 of Set 13 | sagar
# Processing Record 33 of Set 13 | tamandare
# Processing Record 34 of Set 13 | burlington
# Processing Record 35 of Set 13 | kungurtug
# Processing Record 36 of Set 13 | manono
# Processing Record 37 of Set 13 | san patricio
# Processing Record 38 of Set 13 | vagur
# Processing Record 39 of Set 13 | iquitos
# Processing Record 40 of Set 13 | pauini
# Processing Record 41 of Set 13 | herzogenbuchsee
# Processing Record 42 of Set 13 | kendari
# Processing Record 43 of Set 13 | chapleau
# Processing Record 44 of Set 13 | caruray
# Processing Record 45 of Set 13 | bam
# Processing Record 46 of Set 13 | hare bay
# Processing Record 47 of Set 13 | asyut
# Processing Record 48 of Set 13 | santa flavia
# Processing Record 49 of Set 13 | iberia
# Processing Record 50 of Set 13 | puerto penasco
# Processing Record 1 of Set 14 | miracema do tocantins
# Processing Record 2 of Set 14 | bulgan
# Processing Record 3 of Set 14 | porterville
# Processing Record 4 of Set 14 | zyryanka
# Processing Record 5 of Set 14 | waipawa
# Processing Record 6 of Set 14 | baoying
# Processing Record 7 of Set 14 | kutum
# Processing Record 8 of Set 14 | zaltan
# Processing Record 9 of Set 14 | graciano sanchez
# Processing Record 10 of Set 14 | labuan
# Processing Record 11 of Set 14 | ust-maya
# Processing Record 12 of Set 14 | hamina
# Processing Record 13 of Set 14 | riyadh
# Processing Record 14 of Set 14 | mabaruma
# Processing Record 15 of Set 14 | dunedin
# Processing Record 16 of Set 14 | swan hill
# Processing Record 17 of Set 14 | gombong
# Processing Record 18 of Set 14 | awjilah
# Processing Record 19 of Set 14 | vizinga
# Processing Record 20 of Set 14 | portree
# Processing Record 21 of Set 14 | yarmouth
# Processing Record 22 of Set 14 | imbituba
# Processing Record 23 of Set 14 | chachapoyas
# Processing Record 24 of Set 14 | tokzar
# City not found. Skipping...
# Processing Record 25 of Set 14 | kanadukathan
# Processing Record 26 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 14 | dargaville
# Processing Record 28 of Set 14 | qaqortoq
# Processing Record 29 of Set 14 | orlovskiy
# Processing Record 30 of Set 14 | boundiali
# Processing Record 31 of Set 14 | andenes
# Processing Record 32 of Set 14 | lumberton
# Processing Record 33 of Set 14 | atambua
# Processing Record 34 of Set 14 | shawinigan
# Processing Record 35 of Set 14 | sakhon nakhon
# Processing Record 36 of Set 14 | kedougou
# Processing Record 37 of Set 14 | winnemucca
# Processing Record 38 of Set 14 | ridgetown
# Processing Record 39 of Set 14 | biloela
# Processing Record 40 of Set 14 | guiglo
# Processing Record 41 of Set 14 | labuhan
# Processing Record 42 of Set 14 | kamenka
# Processing Record 43 of Set 14 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 44 of Set 14 | garchitorena
# Processing Record 45 of Set 14 | pyapon
# Processing Record 46 of Set 14 | athens
# Processing Record 47 of Set 14 | at-bashi
# Processing Record 48 of Set 14 | zima
# Processing Record 49 of Set 14 | oboyan
# Processing Record 50 of Set 14 | las vegas
# Processing Record 1 of Set 15 | denizli
# Processing Record 2 of Set 15 | baykalsk
# Processing Record 3 of Set 15 | ayan
# Processing Record 4 of Set 15 | yagodnoye
# Processing Record 5 of Set 15 | palembang
# Processing Record 6 of Set 15 | iquique
# Processing Record 7 of Set 15 | cheremukhovo
# Processing Record 8 of Set 15 | gravelbourg
# Processing Record 9 of Set 15 | qui nhon
# Processing Record 10 of Set 15 | ambanja
# Processing Record 11 of Set 15 | sanming
# Processing Record 12 of Set 15 | santiago del estero
# Processing Record 13 of Set 15 | chicama
# Processing Record 14 of Set 15 | skibbereen
# Processing Record 15 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 15 | marsa matruh
# Processing Record 17 of Set 15 | colares
# Processing Record 18 of Set 15 | victor harbor
# Processing Record 19 of Set 15 | ginda
# Processing Record 20 of Set 15 | swellendam
# Processing Record 21 of Set 15 | olafsvik
# Processing Record 22 of Set 15 | melilla
# Processing Record 23 of Set 15 | bataipora
# Processing Record 24 of Set 15 | linhares
# Processing Record 25 of Set 15 | chowchilla
# Processing Record 26 of Set 15 | pingxiang
# Processing Record 27 of Set 15 | liwale
# Processing Record 28 of Set 15 | kirkwall
# Processing Record 29 of Set 15 | paamiut
# Processing Record 30 of Set 15 | deputatskiy
# Processing Record 31 of Set 15 | nandurbar
# Processing Record 32 of Set 15 | sao jose da coroa grande
# Processing Record 33 of Set 15 | la gaulette
# City not found. Skipping...
# Processing Record 34 of Set 15 | ostersund
# Processing Record 35 of Set 15 | enumclaw
# Processing Record 36 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 15 | bangassou
# Processing Record 38 of Set 15 | banikoara
# Processing Record 39 of Set 15 | laredo
# Processing Record 40 of Set 15 | alta
# Processing Record 41 of Set 15 | ormara
# Processing Record 42 of Set 15 | huanren
# Processing Record 43 of Set 15 | north platte
# Processing Record 44 of Set 15 | baraki barak
# Processing Record 45 of Set 15 | yar-sale
# Processing Record 46 of Set 15 | kamaishi
# Processing Record 47 of Set 15 | argenta
# Processing Record 48 of Set 15 | tessalit
# Processing Record 49 of Set 15 | fare
# Processing Record 50 of Set 15 | puerto quijarro
# Processing Record 1 of Set 16 | trani
# Processing Record 2 of Set 16 | polur
# Processing Record 3 of Set 16 | gondanglegi
# Processing Record 4 of Set 16 | kaeo
# Processing Record 5 of Set 16 | cedral
# Processing Record 6 of Set 16 | oussouye
# Processing Record 7 of Set 16 | cacapava
# Processing Record 8 of Set 16 | gat
# Processing Record 9 of Set 16 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 16 | prince rupert
# Processing Record 11 of Set 16 | halifax
# Processing Record 12 of Set 16 | huixtla
# Processing Record 13 of Set 16 | kirakira
# Processing Record 14 of Set 16 | murgab
# Processing Record 15 of Set 16 | sungai padi
# Processing Record 16 of Set 16 | arman
# Processing Record 17 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 16 | svetlyy yar
# Processing Record 19 of Set 16 | yingcheng
# Processing Record 20 of Set 16 | kangaatsiaq
# Processing Record 21 of Set 16 | sernur
# Processing Record 22 of Set 16 | makat
# Processing Record 23 of Set 16 | hecun
# Processing Record 24 of Set 16 | camopi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 711

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Butaritari   3.0707  172.7902     81.27        69          15
# 1      Athabasca  54.7169 -113.2854     46.81        61         100
# 2         Bonfim   3.0833  -59.9500     92.25        49          91
# 3      Cape Town -33.9258   18.4232     67.08        61           0
# 4        Talnakh  69.4865   88.3972     23.47        96          99
# 5        Iqaluit  63.7506  -68.5145     40.73        70          20
# 6        Rikitea -23.1203 -134.9692     74.64        81         100
# 7       Rathdrum  47.8137 -116.8920     57.00        67          90
# 8          Vaini -21.2000 -175.2000     69.96       100          75
# 9  Half Moon Bay  37.4636 -122.4286     73.15        68          90
#
#    Wind Speed Country Current Description
# 0       13.82      KI          few clouds
# 1       14.45      CA     overcast clouds
# 2        4.07      BR     overcast clouds
# 3        1.01      ZA           clear sky
# 4        3.85      RU          light snow
# 5        4.00      CA          few clouds
# 6       18.86      PF          light rain
# 7        4.00      US     overcast clouds
# 8        2.30      TO          light rain
# 9        0.00      US     overcast clouds

# %%
# Reorder the columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed, so they are easy to read
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Butaritari      KI   3.0707  172.7902     81.27        69          15
# 1      Athabasca      CA  54.7169 -113.2854     46.81        61         100
# 2         Bonfim      BR   3.0833  -59.9500     92.25        49          91
# 3      Cape Town      ZA -33.9258   18.4232     67.08        61           0
# 4        Talnakh      RU  69.4865   88.3972     23.47        96          99
# 5        Iqaluit      CA  63.7506  -68.5145     40.73        70          20
# 6        Rikitea      PF -23.1203 -134.9692     74.64        81         100
# 7       Rathdrum      US  47.8137 -116.8920     57.00        67          90
# 8          Vaini      TO -21.2000 -175.2000     69.96       100          75
# 9  Half Moon Bay      US  37.4636 -122.4286     73.15        68          90
#
#    Wind Speed Current Description
# 0       13.82          few clouds
# 1       14.45     overcast clouds
# 2        4.07     overcast clouds
# 3        1.01           clear sky
# 4        3.85          light snow
# 5        4.00          few clouds
# 6       18.86          light rain
# 7        4.00     overcast clouds
# 8        2.30          light rain
# 9        0.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
